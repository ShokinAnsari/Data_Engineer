# %%
names=["ravi","naveen","king","shin",]
names
# Out:
# ['ravi', 'naveen', 'king', 'shin']

# %%
for i in names:
    print(f"Hello  {i}")
# Out:
# Hello  ravi
# Hello  naveen
# Hello  king
# Hello  shin

# %%
# Using List Comprehension
arr=["Hello " + i for i in names]
print(arr)
# Out:
# ['Hello ravi', 'Hello naveen', 'Hello king', 'Hello shin']

# %%
# Exception Handling
try:
    x=1/0
except ZeroDivisionError:
    print("divided by zero")
    print("Executed when exception occur")
else: #this optional
    print("executed when exception will not occurr")
finally: #this optional
     print("final block executed always")
# Out:
# divided by zero
# Executed when exception occur
# final block executed always

# %%
# File Handling 
with open("file.txt",w) as f:
    f.write("This is my file")

# %%
# Lambda function -> temporary funtn with same expression that are used frequently
square_lambda=lambda arg: arg**2 
print(square_lambda(10))
# Out:
# 100
