# %%
#Working with Datetime format
import pandas as pd

# %%
df=pd.DataFrame({
    'date':['12/10/2000','15/11/2000','20/12/2000'],
    'value':[2,3,4]
})
df
# Out:
#          date  value
# 0  12/10/2000      2
# 1  15/11/2000      3
# 2  20/12/2000      4

# %%
df.info() # here date is in object form change it to datetime datatype
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3 non-null      object
#  1   value   3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 180.0+ bytes

# %%
df['date']=pd.to_datetime(df['date'], errors='ignore')
df
# Out:
# C:\Users\shoki\AppData\Local\Temp\ipykernel_4008\2820289300.py:1: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   df['date']=pd.to_datetime(df['date'], errors='ignore')
#         date  value
# 0 2000-12-10      2
# 1        NaT      3
# 2        NaT      4

# %%
df['date']=pd.to_datetime(df['date'], errors='coerce')
df
# Out:
#         date  value
# 0 2000-12-10      2
# 1        NaT      3
# 2        NaT      4

# %%
data_frame=pd.DataFrame({
    'year':[2015,2016,2017],
    'month':[5,6,7],
    'day':[1,2,3]
})
data_frame
# Out:
#    year  month  day
# 0  2015      5    1
# 1  2016      6    2
# 2  2017      7    3

# %%
x['date']=pd.to_datetime(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 x['date']=pd.to_datetime(df)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\tools\datetimes.py:1075, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1075     result = _assemble_from_unit_mappings(arg, errors, utc)
#    1076 elif isinstance(arg, Index):
#    1077     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\tools\datetimes.py:1191, in _assemble_from_unit_mappings(arg, errors, utc)
#    1189 if len(req):
#    1190     _required = ",".join(req)
# ...
